# %%
import cv2
import pytesseract
from PIL import Image
# Read image from which text needs to be extracted
img = cv2.imread("/home/webwerks/Desktop/passport/CustNID.19093570011.jpg")

# Preprocessing the image starts

# Convert the image to gray scale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Performing OTSU threshold
ret, thresh1 = cv2.threshold(gray, 0, 255, cv2.THRESH_OTSU | cv2.THRESH_BINARY_INV)

# Specify structure shape and kernel size.
# Kernel size increases or decreases the area
# of the rectangle to be detected.
# A smaller value like (10, 10) will detect
# each word instead of a sentence.
rect_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (18, 18))

# Appplying dilation on the threshold image
dilation = cv2.dilate(thresh1, rect_kernel, iterations = 1)

# Finding contours
contours, hierarchy = cv2.findContours(dilation, cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)

# %%
# Creating a copy of image
im2 = img.copy()

# A text file is created and flushed
file = open("op1.txt", "w+")
file.write("")
file.close()

# Looping through the identified contours
# Then rectangular part is cropped and passed on
# to pytesseract for extracting text from it
# Extracted text is then written into the text file
for cnt in contours:
    
    x, y, w, h = cv2.boundingRect(cnt)
    
    # Drawing a rectangle on copied image
    rect = cv2.rectangle(im2, (x, y), (x + w, y + h), (0, 255, 0), 2)
    
    # Cropping the text block for giving input to OCR
    cropped = im2[y:y + h, x:x + w]
    
    # Open the file in append mode
    file = open("op1.txt", "a")
    
    # Apply OCR on the cropped image
    text = pytesseract.image_to_string(cropped, lang='ara')
    
    # Appending the text into file
    file.write(text)
    cv2.imshow('cropped',cropped)

# %%
# extract text from all the images in a folder
# storing the text in a single file
from PIL import Image
import pytesseract as pt
import os
	
def main():
	# path for the folder for getting the raw images
	path ="/home/webwerks/Desktop/National_IDs_Images_Front_100-1/Images_100"

	# link to the file in which output needs to be kept
	fullTempPath ="/home/webwerks/Desktop/Data_Extraction/image_output.txt"

	# iterating the images inside the folder
	for imageName in os.listdir(path):
		inputPath = os.path.join(path, imageName)
		img = Image.open(inputPath)

		# applying ocr using pytesseract for python
		text = pt.image_to_string(img, lang ="ara")

		# saving the text for appending it to the output.txt file
		# a + parameter used for creating the file if not present
		# and if present then append the text content
		file1 = open(fullTempPath, "a+")

		# providing the name of the image
		file1.write(imageName+"\n")

		# providing the content in the image
		file1.write(text+"\n")
		file1.close()
        

	# for printing the output file
	file2 = open(fullTempPath, 'r')
	print(file2.read())
	file2.close()		


if __name__ == '__main__':
	main()
# Out:
# CustNID_19093680010.jpg
#
#
# CustNID_19110040023.jpg
#
# CustNID_19103760012.jpg
#
#
#
#
# -- ل ابوالحسن 2
#
# 4
# اي هه
#
# مركرٌ دكرئس - الدقهلية ١
#
# 01
#
# 69395553
#
#
#
# CustNID_19110030039.jpg
#
#
# عيه” نجه
# 7 ملف . وو
#
# 8 ٌ 7 : 2
# عه 1[ ١؟ ا كبيج رو
#
# 61029812
#
# CustNID_19110040027.jpg
#
# CustNID_19105630012.jpg
#
#
# CustNID_19083270008.jpg
#
#
# CustNID_19110020032.jpg
#
#
# ١
#
#
#
#
#
# 3 61/49 77 4
#
# CustNID_19110010064.jpg
#
#
# CustNID_19073860030.jpg
#
#
# CustNID_19090180038.jpg
#
#
#
#
#
#
# CustNID_19100140030.jpg
#
# CustNID_19096270031.jpg
#
#
# CustNID_19103610031.jpg
#
#
# CustNID_19103760025.jpg
# مح انوت اسرد
#
# 0 ييز
# بطاقة تحقيق الشخصية
# اج
#
# ف امنا
#
# محمد صلاح الدين على زوال
#
# ل
#
# المنصورة ثان - الدقهلية
#
# ل شك 0ه . /: + ١
# 22101
#
#
#
# CustNID_19070240096.jpg
#
#
# CustNID_19105330036.jpg
#
# CustNID_19110010066.jpg
#
#
# CustNID_19106170082.jpg
#
#
# CustNID_19110010063.jpg
#
#
# CustNID_19106180085.jpg
#
#
# CustNID_19110050030.jpg
#
#
# عون .و ١
#
# 671745
#
#
#
#
# أو. ,
#
# 1-0 ا ا 7
#
#
#
#
# CustNID_1910050530046.jpg
# ومن ض | ليس
#
# بظاقة حقيق الشخصية
#
# ع
#
# 2 5.١541"
#
#
#
# CustNID_19103920026.jpg
#
#
# CustNID_19105450092.jpg
#
#
# CustNID_19105510012.jpg
#
#
# صر
#
# CustNID_19105350037.jpg
# 7 6 ١ .+
# 2 هم اه «< ١ 50 ١ ١ :
# 7 وه 0 7 ”#ن -< 7 0 0 7 صر / تر سيم ١
#
# -
#
# ١
#
# وليشه
# أاحمد احمد محمد حرب
#
# ع ش محمد على اسماعيل-|احمدد بسسيو سى
# حدائق القبه - القاهره
#
# 24 4؛ 25 كه 4١ .ملا ؟
#
# 8850+ 7
#
#
#
# CustNID_19110040022.jpg
#
# CustNID_19110050031.jpg
#
#
#
# ا د ا ا
#
# و د 2
# دك 00 6
#
# ومضان
# ؟” ش سيد حجازى-ترعة ز
# بولاق الدكرور - الجيزه
#
#
#
#
# م #4 زع ويد ها أ
#
# CustNID_19103850060.jpg
#
#
# CustNID_19093760021.jpg
#
#
# CustNID_19095190049.jpg
#
#
# CustNID_19065680004.jpg
#
#
# CustNID_19106380002.jpg
#
#
# CustNID_19105290055.jpg
#
#
# CustNID_19076180051.jpg
#
#
# -
#
# CustNID_19105110036.jpg
# ؛ ش الامام عا
# الزقازيق ثان
#
# / + 1*5 "١ 6١ ه6. ؟و؟
# 6 ا
#
#
#
# CustNID_19105430101.jpg
# 177 2 ليما
# 5 هن - درل حب
# بطاقة تحقيق الشخصية
# صببرى
# محمد عبدالمنعم محمد
#
# مركز المنشاه - سوهاج.
#
#
#
#
# ةو لالس و 1 0
# 28
#
# CustNID_19080230019.jpg
#
#
# CustNID_19103730006.jpg
#
#
#
#
# السيد فتح الله ابراهيم 1
# ميت شهاله
# مركز الشهداء - المنوفية
#
# 4
#
# 044 ب راود 59 ؟
#
#
#
# اللا ع 20
# لحفى الشخصة
#
# 1 .| ؟وو١
#
# ١ حم ةج ند حت ند عن ىا
#
# CustNID_19110020043.jpg
#
#
# 9 ' 1 ار
#
# CustNID_19095440011.jpg
#
#
# ل يت
# بطاقة تعفيق الشخصية "
#
# عمرو
#
# عثمان عبدالقتاح الجندى
#
# السلا م
#
# مركز بدر - البخيرة
#
# الوكلا 11
#
# 7»
#
# 7 | 1ءآ+ض
#
# CustNID_19093560038.jpg
#
#
# CustNID_19110040026.jpg
#
# CustNID_19073760009.jpg
#
# CustNID_18083110026.jpg
#
#
# 3 ريمض الدَبِيًزا
# ه2022 > ل 070 ليان رع ويا ها
# بطاقة تحقيق الشخصية
# |" >
# محمد
# سيد محمد مرسى
# ش مسجد الرحمن ٠
#
# الخصوص - القليوبية .
#
#
#
# 41 250209 إن عاالى5 ابام
#
# 692 0614م
#
# CustNID_19110030041.jpg
#
#
# عيه” نجه
# 7 ملف . وو
#
# 8 ٌ 7 : 2
# عه 1[ ١؟ ا كبيج رو
#
# 61029812
#
# CustNID_19100130017.jpg
#
# CustNID_19083590012.jpg
# وو جد و
# <+5#” لومم كه
# باق لين ١
# الف
# حسين
#
# محمد احمد محمد عزالدين
#
#
#
# اش حسنى محمود من عبدالحميد مكى
# البساتين - القاهره
#
#
#
# جب
#
# 01١ 4ق 8م ” ككزم . زخزرو؟
# 4
# دا د
#
# CustNID_19093300033.jpg
# اشرف
# ؛ "كش جمال الدين الافغانى مساكن اسكو
# ا خيمه ثان - القليوبية
#
# بس لانيو . رمم
# 221
#
#
#
# CustNID_19110010067.jpg
#
#
# CustNID_19075310015.jpg
#
#
# CustNID_19110010069.jpg
#
#
# CustNID_19103980033.jpg
#
#
#
# ف 2
#
# منشأة ابكار -المريوطية
#
#
#
# 1106145
#
#
#
# CustNID_19070070037.jpg
#
#
# CustNID_19110010065.jpg
#
#
# CustNID_19093910022.jpg
#
#
# CustNID_19110050027.jpg
# 5 عن لايس 7 ةي ارس
# وق مض لجبيزا
# بطاقة تحقيق الشخصية
#
# عاطف
#
# على عبده على 1
# 407 ش مستجد-ش النصر-الطوابق-فيصل
# الهرم - الجيزه
#
# "ا/ا ؟ؤ.. ”"؟ ا" ".لك ؟"
#
#
#
# CustNID_19103690064.jpg
#
#
# CustNID_19110010047.jpg
#
#
# CustNID_19033980017.jpg
#
#
# ل
#
# || منيع
# متووج -
#
# ١ البطاقة سارية حتى 7/18/480.؟
#
#
#
# CustNID_19085470059.jpg
#
#
# CustNID_19095760012.jpg
#
#
#
#
# تك
#
# مسعد عبدالرحمن درغام
# فيلا ا-مجاورة "-الحى ؟ شرق
# الشروق - القاهره
#
# 5 فق 4”#. 4 , “ان ب
#
#
#
#
# 638 اك
# 107
#
#
#
# CustNID_19083600012.jpg
# ع و سي
# 0
#
# بطاقة تحقيق الشخصية
# سراج :
# عبدالفتاح عبدالمعطى سعد زايد 3
# ٠ ١مديتة الفسطاط الجديدة-مجاورة " 1 1
# مصر القديمه - القاهره :
#
#
#
#
#
# CustNID_19043860011.jpg
#
#
# CustNID_19070240004.jpg
#
#
# CustNID_19110010061.jpg
#
#
# CustNID_19103920063.jpg
#
#
# CustNID_19065440026.jpg
#
#
# «الرسول التقيره ََ 4
# د عيها 4 5
# قرية الطوة .»©
# مركز كوم حمادة + البعيرة ١
#
# 3 9/1١
# لال 1 “ال
#
# 2
#
# CustNID_19100060004.jpg
# 0061 عادز 11 وانا5 501
# كينا
#
# 8
#
# كه
#
# 722726 6 اال
#
#
#
# CustNID_19093780034.jpg
#
#
# CustNID_19085500070.jpg
#
# CustNID_19103930145.jpg
#
# CustNID_19105230054.jpg
#
#
# السبيد توفيق العزبى
# الكوم ١
# مركز رشيد > البحيية !١
#
#
#
# را ب
# 211112104
#
# بنن أأى مزاخ" #١١
#
#
#
# CustNID_19093700072.jpg
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -
#
#
#
# التاريخ لا
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1 الرقم القومى + 191051759]101985
# حاقز |علارة أغرى |علاوة اجتماعية|مزايا نقدية أخرى أي اضاقى أج. 2-0
# |( 1 7 0 رك كمه . 3 لنقل م ب 0 :
# 5 غات 2 6ك
# 2
# .٠ 2 0 0
# الضرائب لتأمينات | - 5
# 7 3 - 0
#
#
#
#
#
#
#
# CustNID_19100010106.jpg
#
#
# CustNID_19105580039.jpg
# العقال القبلى ١
# مركز البدارى - اسيوط
#
#
#
# CustNID_19110010060.jpg
#
#
# CustNID_19105160056.jpg
#
# CustNID_19110010059.jpg
#
#
# CustNID_19093670005.jpg
# 0 0
# ااعرل 1 3 6 5
# 0 م 2 11 ع
#
# بطاقة تحقيق الشخصية
#
# مححسن
#
# عاشور حسن محمد
# اش عبده فرحات
# . البسآتين - القاهره -
#
# 7 644870 سيا
#
#
#
# CustNID_19100150042.jpg
#
#
# CustNID_19105290040.jpg
# ع
#
# بطافة تحقيق الشخصية
#
# اسلام
# عبدالرحمن محمد حسين
#
# الاعقاب
# مركز اسوان - أسوان
#
# 008 يا + 4 ار 1"
#
#
#
# CustNID_19103400070.jpg
# ندل
# ع
# 1
# 0و
# ند
# 5
# دل
# 1
# 5
# 2
# 0-6
# ص
#
#
#
# 691 0 1
#
# CustNID_19093570011.jpg
# 1 ع د اص و3 ع سه
# بطاقة نحقيق الشخصية
# وليد
# الابعديه<-.ش عثمان بن مظعون
# جرجا - سوهاج
#
#
#
# وو ع ونم هو وو 1 »7 5352م ة!
#
# CustNID_19110020046.jpg
#
#
# CustNID_19073690021.jpg
#
#
# CustNID_19110040019.jpg
#
# CustNID_19110020053.jpg
#
#
# CustNID_19103590029.jpg
#
#
# CustNID_19095440012.jpg
# 0-35
# مركز بدز”- البحيرة
#
# ااا ا هو “ا 7
#
# .م١
#
# 266229
#
# CustNID_19106710039.jpg
#
#
# CustNID_19103300110.jpg
